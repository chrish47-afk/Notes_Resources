# %%
ls
# Out:
#  dependency_map_ectopic.csv       python_shell.sh
#  epi_ids_ectopic.csv              save_ectopic.py
#  maternal_core_ectopic.py         submit_jobs_2024_Ectopic.ipynb
#  maternal_core_ectopic_doc.docx  '~$ternal_core_ectopic_doc.docx'

# %%
#################################################################################################
#################################################################################################
# Ectopic
#################################################################################################
#################################################################################################

# %%
import subprocess
import pandas as pd
import numpy as np
import os
import re
from datetime import datetime
import time
from db_queries import get_best_model_versions
import getpass
import time
import gbd.constants as gbd

### TODO: Add a way to be able to submit Zero_Fistula and Fistula at the same
###       time, as currently the job would fail as the me_id for Fistula would
###       not have a model version id returned by get_model_versions, which is
###       used for the adjustments job name. Current workaround is to run
###       Zero_Fistula first (with zero=True) and once that all is done
###       then run Fistula (with zero=False).
################################################################################
# Please read the readme.txt in this repo. It will explain the whole strategy
################################################################################

# set round id, years to execute, and boolean for fistula
release_id = 33 #GBD 2023 Additional Publications
yearvals = [1990, 1995, 2000, 2005, 2010, 2015, 2020, 2022, 2023, 2024]
zero = True #True#False

# set up stdout and stderr
username = getpass.getuser()
#root = os.path.join('/share/scratch/users/', username)
root = os.path.join('/share/scratch/projects/rgud/Ectopic_Pregnancy_Exp_2025/')
error_path = "/mnt/share/scratch/users/chrish47/errors/%x.e%j"
output_path = "/mnt/share/scratch/users/chrish47/output/%x.o%j"

if not os.path.exists(error_path):
    os.makedirs(error_path)
if not os.path.exists(output_path):
    os.makedirs(output_path)

# pull in dependency map
dep_map = pd.read_csv('{}/dependency_map_ectopic_exp.csv'.format(os.getcwd()))
print(dep_map)

""" create new dataframe that converts all values in the dep_map to ints and 
matches each output_me with each of its input_mes """
columns = ['input_me','output_me']
extended_map = pd.DataFrame(columns=columns)
for index, row in dep_map.iterrows():
    ins = [int(x) for x in str(row.input_me).split(';')]
    outs = [int(x) for x in str(row.output_mes).split(';')]
    df = pd.DataFrame(columns=columns, data=list(zip(np.repeat(ins, len(outs)), 
        outs*len(ins)))) 
    extended_map = extended_map.append(df, ignore_index=True)
        
# make timestamped output folders
date_regex = re.compile('\W')
date_unformatted = str(datetime.now())[0:13]
c_date = date_regex.sub('_', date_unformatted)

#Automatic data folder vs Manual#
#base_dir = os.path.join(root, 'nonfatal_maternal', '{}'.format(c_date))
base_dir = os.path.join(root, 'nonfatal_maternal', '2025_02_25_14')
#/mnt/share/scratch/projects/rgud/Ectopic_Pregnancy_Exp_2025/nonfatal_maternal/2025_02_25_14
print(base_dir)

for output_me in extended_map.output_me.unique():
    out_dir = (os.path.join(base_dir, str(output_me)))
    if not os.path.exists(out_dir):
        os.makedirs(out_dir)

""" grab version ids for all input models. This strategy assumes that no new 
dismod source models have been marked best since the start of the LBA 
code. """
model_version_list = extended_map.input_me.unique()
mvid_df = get_best_model_versions(entity='modelable_entity',
    ids=model_version_list, release_id=release_id)
print(model_version_list)
print(mvid_df)
# Out:
#    input_me                                       output_mes class_name
# 0     10484  10485;28983;28984;28985;32537;32539;32538;32540    Ectopic
# /share/scratch/projects/rgud/Ectopic_Pregnancy_Exp_2025/nonfatal_maternal/2025_02_25_14
# /tmp/ipykernel_843124/2348822126.py:53: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   extended_map = extended_map.append(df, ignore_index=True)
# [10484]
#    cause_id         cause_name covariate_id covariate_name rei_id rei_name  \
# 0       374  Ectopic pregnancy         None           None   None     None
#
#    modelable_entity_id                              modelable_entity_name  \
# 0                10484  Ectopic pregnancy incidence ratio (events per ...
#
#    model_type_id model_type  model_version_id  release_id          best_start  \
# 0              3     dismod            861397          16 2024-09-10 17:55:20
#
#         date_inserted                                        description
# 0 2024-09-09 18:17:10  Scilit_deno_adjusted_CI4_no_envelope_no_ms_som...

# %%
###############################################################Adjusting Ectopic Denominator
adjust_job_list = []
for index, row in dep_map.iterrows():
    class_name = row['class_name']
    print(class_name)
    input_me = row['input_me']
    print(input_me)
    output_me = row['output_mes']
    print(output_me)

    #if class_name == "Fistula" and zero:
    #    hold = save_job_name
    #else:
    #    hold = "no_holds"

    for year in yearvals:
        job_name = 'adj_{cn}_{y}'.format(cn=class_name, y=year)
        """ this line is to facilitate testing one class at a time, 
        change as needed """
        if (class_name not in ["abcdefghijk..."]):
            adjust_job_list.append(job_name)
            call = ('sbatch -c 10 --mem=50G'
                    ' -p long.q -C archive'
                    ' -A proj_rgud'
                    ' -t 12:30:00'
                    ' -o {o}'
                    ' -e {e}'
                    ' -J {jn}'
                    ' python_shell.sh'
                    ' maternal_core_ectopic_experimental.py'
                    ' {arg1} {arg2} {arg3} "{arg4}" "{arg5}" {arg6}'.format(
                        o=output_path, e=error_path, jn=job_name, 
                        arg1=class_name, arg2=base_dir, arg3=year, 
                        arg4=input_me, arg5=output_me, arg6=release_id))
            subprocess.check_output(call, shell=True)
            print(call)
# Out:
# Ectopic
# 10484
# 10485;28983;28984;28985;32537;32539;32538;32540
# sbatch -c 10 --mem=50G -p long.q -C archive -A proj_rgud -t 12:30:00 -o /mnt/share/scratch/users/chrish47/output/%x.o%j -e /mnt/share/scratch/users/chrish47/errors/%x.e%j -J adj_Ectopic_1990 python_shell.sh maternal_core_ectopic_experimental.py Ectopic /share/scratch/projects/rgud/Ectopic_Pregnancy_Exp_2025/nonfatal_maternal/2025_02_25_14 1990 "10484" "10485;28983;28984;28985;32537;32539;32538;32540" 16
# sbatch -c 10 --mem=50G -p long.q -C archive -A proj_rgud -t 12:30:00 -o /mnt/share/scratch/users/chrish47/output/%x.o%j -e /mnt/share/scratch/users/chrish47/errors/%x.e%j -J adj_Ectopic_1995 python_shell.sh maternal_core_ectopic_experimental.py Ectopic /share/scratch/projects/rgud/Ectopic_Pregnancy_Exp_2025/nonfatal_maternal/2025_02_25_14 1995 "10484" "10485;28983;28984;28985;32537;32539;32538;32540" 16
# sbatch -c 10 --mem=50G -p long.q -C archive -A proj_rgud -t 12:30:00 -o /mnt/share/scratch/users/chrish47/output/%x.o%j -e /mnt/share/scratch/users/chrish47/errors/%x.e%j -J adj_Ectopic_2000 python_shell.sh maternal_core_ectopic_experimental.py Ectopic /share/scratch/projects/rgud/Ectopic_Pregnancy_Exp_2025/nonfatal_maternal/2025_02_25_14 2000 "10484" "10485;28983;28984;28985;32537;32539;32538;32540" 16
# sbatch -c 10 --mem=50G -p long.q -C archive -A proj_rgud -t 12:30:00 -o /mnt/share/scratch/users/chrish47/output/%x.o%j -e /mnt/share/scratch/users/chrish47/errors/%x.e%j -J adj_Ectopic_2005 python_shell.sh maternal_core_ectopic_experimental.py Ectopic /share/scratch/projects/rgud/Ectopic_Pregnancy_Exp_2025/nonfatal_maternal/2025_02_25_14 2005 "10484" "10485;28983;28984;28985;32537;32539;32538;32540" 16
# sbatch -c 10 --mem=50G -p long.q -C archive -A proj_rgud -t 12:30:00 -o /mnt/share/scratch/users/chrish47/output/%x.o%j -e /mnt/share/scratch/users/chrish47/errors/%x.e%j -J adj_Ectopic_2010 python_shell.sh maternal_core_ectopic_experimental.py Ectopic /share/scratch/projects/rgud/Ectopic_Pregnancy_Exp_2025/nonfatal_maternal/2025_02_25_14 2010 "10484" "10485;28983;28984;28985;32537;32539;32538;32540" 16
# sbatch -c 10 --mem=50G -p long.q -C archive -A proj_rgud -t 12:30:00 -o /mnt/share/scratch/users/chrish47/output/%x.o%j -e /mnt/share/scratch/users/chrish47/errors/%x.e%j -J adj_Ectopic_2015 python_shell.sh maternal_core_ectopic_experimental.py Ectopic /share/scratch/projects/rgud/Ectopic_Pregnancy_Exp_2025/nonfatal_maternal/2025_02_25_14 2015 "10484" "10485;28983;28984;28985;32537;32539;32538;32540" 16
# sbatch -c 10 --mem=50G -p long.q -C archive -A proj_rgud -t 12:30:00 -o /mnt/share/scratch/users/chrish47/output/%x.o%j -e /mnt/share/scratch/users/chrish47/errors/%x.e%j -J adj_Ectopic_2020 python_shell.sh maternal_core_ectopic_experimental.py Ectopic /share/scratch/projects/rgud/Ectopic_Pregnancy_Exp_2025/nonfatal_maternal/2025_02_25_14 2020 "10484" "10485;28983;28984;28985;32537;32539;32538;32540" 16
# sbatch -c 10 --mem=50G -p long.q -C archive -A proj_rgud -t 12:30:00 -o /mnt/share/scratch/users/chrish47/output/%x.o%j -e /mnt/share/scratch/users/chrish47/errors/%x.e%j -J adj_Ectopic_2022 python_shell.sh maternal_core_ectopic_experimental.py Ectopic /share/scratch/projects/rgud/Ectopic_Pregnancy_Exp_2025/nonfatal_maternal/2025_02_25_14 2022 "10484" "10485;28983;28984;28985;32537;32539;32538;32540" 16
# sbatch -c 10 --mem=50G -p long.q -C archive -A proj_rgud -t 12:30:00 -o /mnt/share/scratch/users/chrish47/output/%x.o%j -e /mnt/share/scratch/users/chrish47/errors/%x.e%j -J adj_Ectopic_2023 python_shell.sh maternal_core_ectopic_experimental.py Ectopic /share/scratch/projects/rgud/Ectopic_Pregnancy_Exp_2025/nonfatal_maternal/2025_02_25_14 2023 "10484" "10485;28983;28984;28985;32537;32539;32538;32540" 16
# sbatch -c 10 --mem=50G -p long.q -C archive -A proj_rgud -t 12:30:00 -o /mnt/share/scratch/users/chrish47/output/%x.o%j -e /mnt/share/scratch/users/chrish47/errors/%x.e%j -J adj_Ectopic_2024 python_shell.sh maternal_core_ectopic_experimental.py Ectopic /share/scratch/projects/rgud/Ectopic_Pregnancy_Exp_2025/nonfatal_maternal/2025_02_25_14 2024 "10484" "10485;28983;28984;28985;32537;32539;32538;32540" 16

# %%
############################################################################
# Save results in parallel for everything except dismod_dict keys
############################################################################

    # hold = "no_holds"
    
####
dep_map = dep_map.loc[dep_map.class_name != 'Zero_Fistula',:]
adjust_job_list = []
print("test1")
for index, row in dep_map.iterrows():
    class_name = row['class_name']
    input_me = row['input_me']
    output_me = row['output_mes']

    #if class_name == "Fistula" and zero:
    #    hold = 'skip'#save_job_name #Christian: This save_job_name variables is not needed, since we are skipping anyways.
    #else:
    #    hold = "no_holds"
        
    hold = ",".join(adjust_job_list)
    dismod_dict = {
        2624 : ('maternal_sepsis', 377),
        2627 : ('maternal_htn', 827),
        1546 : ('maternal_htn', 829)
    }
    output_mes = [int(x) for x in str(output_me).split(';')]
    epi_upload_list = [x for x in output_mes if x in list(dismod_dict.keys())]
#####

    print("test5")
    hold = ",".join(adjust_job_list)
    save_mes = [x for x in output_mes if x not in list(dismod_dict.keys())]
    for me in save_mes:
        data_dir = os.path.join(base_dir, str(me))
        """ this line is to facilitate testing one bundle at a time, 
        change as needed """
        print(data_dir)
        if me not in [-1]:
            model_ids_str_for_save = ''
            df = extended_map.loc[extended_map.output_me==me,:]
            for index,row in df.iterrows():
                model_ids_str_for_save += ' meid {}, mvid {};'.format(
                    row.input_me, 
                    mvid_df.loc[mvid_df.modelable_entity_id==row.input_me,
                    'model_version_id'].item())
            model_ids_str_for_save = model_ids_str_for_save[:-1] + "."
            call = ('sbatch -c 25 --mem=80G'
                    ' -p long.q -C archive'
                    ' -A proj_rgud'
                    ' -t 12:30:00'
                    ' -o {o}'
                    ' -e {e}'
                    ' -J save_{jn}'
                    ' python_shell.sh'
                    ' save_ectopic_experimental.py'
                    ' {arg1} \'{arg2}\' {arg3} "{arg4}" '.format(o=output_path, 
                        e=error_path, jn=me, arg1=me, 
                        arg2=model_ids_str_for_save, 
                        arg3=data_dir, arg4=release_id))
            subprocess.check_output(call, shell=True)
            print(call)
        print("test6")
    #check_output
    sleeptime = 5
    print("Sleeping for {} seconds".format(sleeptime))
    time.sleep(sleeptime)
# Out:
# test1
# test5
# /share/scratch/projects/rgud/Ectopic_Pregnancy_Exp_2025/nonfatal_maternal/2025_02_25_14/10485
# sbatch -c 25 --mem=80G -p long.q -C archive -A proj_rgud -t 12:30:00 -o /mnt/share/scratch/users/chrish47/output/%x.o%j -e /mnt/share/scratch/users/chrish47/errors/%x.e%j -J save_10485 python_shell.sh save_ectopic_experimental.py 10485 ' meid 10484, mvid 861397.' /share/scratch/projects/rgud/Ectopic_Pregnancy_Exp_2025/nonfatal_maternal/2025_02_25_14/10485 "33"
# test6
# /share/scratch/projects/rgud/Ectopic_Pregnancy_Exp_2025/nonfatal_maternal/2025_02_25_14/28983
# sbatch -c 25 --mem=80G -p long.q -C archive -A proj_rgud -t 12:30:00 -o /mnt/share/scratch/users/chrish47/output/%x.o%j -e /mnt/share/scratch/users/chrish47/errors/%x.e%j -J save_28983 python_shell.sh save_ectopic_experimental.py 28983 ' meid 10484, mvid 861397.' /share/scratch/projects/rgud/Ectopic_Pregnancy_Exp_2025/nonfatal_maternal/2025_02_25_14/28983 "33"
# test6
# /share/scratch/projects/rgud/Ectopic_Pregnancy_Exp_2025/nonfatal_maternal/2025_02_25_14/28984
# sbatch -c 25 --mem=80G -p long.q -C archive -A proj_rgud -t 12:30:00 -o /mnt/share/scratch/users/chrish47/output/%x.o%j -e /mnt/share/scratch/users/chrish47/errors/%x.e%j -J save_28984 python_shell.sh save_ectopic_experimental.py 28984 ' meid 10484, mvid 861397.' /share/scratch/projects/rgud/Ectopic_Pregnancy_Exp_2025/nonfatal_maternal/2025_02_25_14/28984 "33"
# test6
# /share/scratch/projects/rgud/Ectopic_Pregnancy_Exp_2025/nonfatal_maternal/2025_02_25_14/28985
# sbatch -c 25 --mem=80G -p long.q -C archive -A proj_rgud -t 12:30:00 -o /mnt/share/scratch/users/chrish47/output/%x.o%j -e /mnt/share/scratch/users/chrish47/errors/%x.e%j -J save_28985 python_shell.sh save_ectopic_experimental.py 28985 ' meid 10484, mvid 861397.' /share/scratch/projects/rgud/Ectopic_Pregnancy_Exp_2025/nonfatal_maternal/2025_02_25_14/28985 "33"
# test6
# /share/scratch/projects/rgud/Ectopic_Pregnancy_Exp_2025/nonfatal_maternal/2025_02_25_14/32537
# sbatch -c 25 --mem=80G -p long.q -C archive -A proj_rgud -t 12:30:00 -o /mnt/share/scratch/users/chrish47/output/%x.o%j -e /mnt/share/scratch/users/chrish47/errors/%x.e%j -J save_32537 python_shell.sh save_ectopic_experimental.py 32537 ' meid 10484, mvid 861397.' /share/scratch/projects/rgud/Ectopic_Pregnancy_Exp_2025/nonfatal_maternal/2025_02_25_14/32537 "33"
# test6
# /share/scratch/projects/rgud/Ectopic_Pregnancy_Exp_2025/nonfatal_maternal/2025_02_25_14/32539
# sbatch -c 25 --mem=80G -p long.q -C archive -A proj_rgud -t 12:30:00 -o /mnt/share/scratch/users/chrish47/output/%x.o%j -e /mnt/share/scratch/users/chrish47/errors/%x.e%j -J save_32539 python_shell.sh save_ectopic_experimental.py 32539 ' meid 10484, mvid 861397.' /share/scratch/projects/rgud/Ectopic_Pregnancy_Exp_2025/nonfatal_maternal/2025_02_25_14/32539 "33"
# test6
# /share/scratch/projects/rgud/Ectopic_Pregnancy_Exp_2025/nonfatal_maternal/2025_02_25_14/32538
# sbatch -c 25 --mem=80G -p long.q -C archive -A proj_rgud -t 12:30:00 -o /mnt/share/scratch/users/chrish47/output/%x.o%j -e /mnt/share/scratch/users/chrish47/errors/%x.e%j -J save_32538 python_shell.sh save_ectopic_experimental.py 32538 ' meid 10484, mvid 861397.' /share/scratch/projects/rgud/Ectopic_Pregnancy_Exp_2025/nonfatal_maternal/2025_02_25_14/32538 "33"
# test6
# /share/scratch/projects/rgud/Ectopic_Pregnancy_Exp_2025/nonfatal_maternal/2025_02_25_14/32540
# sbatch -c 25 --mem=80G -p long.q -C archive -A proj_rgud -t 12:30:00 -o /mnt/share/scratch/users/chrish47/output/%x.o%j -e /mnt/share/scratch/users/chrish47/errors/%x.e%j -J save_32540 python_shell.sh save_ectopic_experimental.py 32540 ' meid 10484, mvid 861397.' /share/scratch/projects/rgud/Ectopic_Pregnancy_Exp_2025/nonfatal_maternal/2025_02_25_14/32540 "33"
# test6
# Sleeping for 5 seconds
